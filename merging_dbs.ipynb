# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bom_df = pd.read_csv('./zippedData/bom.movie_gross.csv')

bom_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
tmdb_df = pd.read_csv('./zippedData/tmdb.movies.csv')

tmdb_df.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
bom_tmdb_df = pd.merge(bom_df, tmdb_df, on = 'title', how = 'inner')

bom_tmdb_df.head()
# Out:
#                         title studio  domestic_gross foreign_gross  year  \
# 0                 Toy Story 3     BV     415000000.0     652000000  2010
# 1                   Inception     WB     292600000.0     535700000  2010
# 2         Shrek Forever After   P/DW     238700000.0     513900000  2010
# 3  The Twilight Saga: Eclipse   Sum.     300500000.0     398000000  2010
# 4                  Iron Man 2   Par.     312400000.0     311500000  2010
#
#    Unnamed: 0                genre_ids     id original_language  \
# 0           7          [16, 10751, 35]  10193                en
# 1           4            [28, 878, 12]  27205                en
# 2          38  [35, 12, 14, 16, 10751]  10192                en
# 3          15      [12, 14, 18, 10749]  24021                en
# 4           2            [12, 28, 878]  10138                en
#
#                original_title  popularity release_date  vote_average  \
# 0                 Toy Story 3      24.445   2010-06-17           7.7
# 1                   Inception      27.920   2010-07-16           8.3
# 2         Shrek Forever After      15.041   2010-05-16           6.1
# 3  The Twilight Saga: Eclipse      20.340   2010-06-23           6.0
# 4                  Iron Man 2      28.515   2010-05-07           6.8
#
#    vote_count
# 0        8340
# 1       22186
# 2        3843
# 3        4909
# 4       12368

# %%
bom_df.shape
# Out:
# (3387, 5)

# %%
tmdb_df.shape
# Out:
# (26517, 10)

# %%
bom_tmdb_df.shape
# Out:
# (2703, 14)

# %%
wiki_plot_df = pd.read_csv('./zippedData/wiki_movie_plots_deduped.csv')

wiki_plot_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-52-22e134e86702> in <module>
# ----> 1 wiki_plot_df = pd.read_csv('./zippedData/wiki_movie_plots_deduped.csv')
#       2
#       3 wiki_plot_df.head()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'./zippedData/wiki_movie_plots_deduped.csv' does not exist: b'./zippedData/wiki_movie_plots_deduped.csv'

# %%
wiki_plot_df.rename(columns = {'Title':'title'}, inplace = True)

wiki_plot_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-4613b5acc6aa> in <module>
# ----> 1 wiki_plot_df.rename(columns = {'Title':'title'}, inplace = True)
#       2
#       3 wiki_plot_df.head()
#
# NameError: name 'wiki_plot_df' is not defined

# %%
bom_tmdb_wiki_df = pd.merge(bom_tmdb_df, wiki_plot_df, on = 'title', how = 'inner')

bom_tmdb_wiki_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-8ff15f6ebb16> in <module>
# ----> 1 bom_tmdb_wiki_df = pd.merge(bom_tmdb_df, wiki_plot_df, on = 'title', how = 'inner')
#       2
#       3 bom_tmdb_wiki_df.head()
#
# NameError: name 'wiki_plot_df' is not defined

# %%
bom_tmdb_wiki_df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-418cc8e09013> in <module>
# ----> 1 bom_tmdb_wiki_df.columns
#
# NameError: name 'bom_tmdb_wiki_df' is not defined

# %%
bom_tmdb_wiki_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-a34e28c33d5f> in <module>
# ----> 1 bom_tmdb_wiki_df.shape
#
# NameError: name 'bom_tmdb_wiki_df' is not defined

# %%
mpst_df = pd.read_csv('./zippedData/mpst-movie-plot-synopses-with-tags/mpst_full_data.csv')

mpst_df.head()
# Out:
#      imdb_id                                          title  \
# 0  tt0057603                        I tre volti della paura
# 1  tt1733125  Dungeons & Dragons: The Book of Vile Darkness
# 2  tt0033045                     The Shop Around the Corner
# 3  tt0113862                             Mr. Holland's Opus
# 4  tt0086250                                       Scarface
#
#                                        plot_synopsis  \
# 0  Note: this synopsis is for the orginal Italian...
# 1  Two thousand years ago, Nhagruul the Foul, a s...
# 2  Matuschek's, a gift store in Budapest, is the ...
# 3  Glenn Holland, not a morning person by anyone'...
# 4  In May 1980, a Cuban man named Tony Montana (A...
#
#                                                 tags  split synopsis_source
# 0          cult, horror, gothic, murder, atmospheric  train            imdb
# 1                                           violence  train            imdb
# 2                                           romantic   test            imdb
# 3             inspiring, romantic, stupid, feel-good  train            imdb
# 4  cruelty, murder, dramatic, cult, violence, atm...    val            imdb

# %%
bom_tmdb_mpst_df = pd.merge(bom_tmdb_df, mpst_df, on = 'title', how = 'inner')

bom_tmdb_mpst_df.head()
# Out:
#                         title studio  domestic_gross foreign_gross  year  \
# 0                 Toy Story 3     BV     415000000.0     652000000  2010
# 1                   Inception     WB     292600000.0     535700000  2010
# 2         Shrek Forever After   P/DW     238700000.0     513900000  2010
# 3  The Twilight Saga: Eclipse   Sum.     300500000.0     398000000  2010
# 4                  Iron Man 2   Par.     312400000.0     311500000  2010
#
#    Unnamed: 0                genre_ids     id original_language  \
# 0           7          [16, 10751, 35]  10193                en
# 1           4            [28, 878, 12]  27205                en
# 2          38  [35, 12, 14, 16, 10751]  10192                en
# 3          15      [12, 14, 18, 10749]  24021                en
# 4           2            [12, 28, 878]  10138                en
#
#                original_title  popularity release_date  vote_average  \
# 0                 Toy Story 3      24.445   2010-06-17           7.7
# 1                   Inception      27.920   2010-07-16           8.3
# 2         Shrek Forever After      15.041   2010-05-16           6.1
# 3  The Twilight Saga: Eclipse      20.340   2010-06-23           6.0
# 4                  Iron Man 2      28.515   2010-05-07           6.8
#
#    vote_count    imdb_id                                      plot_synopsis  \
# 0        8340  tt0435761  Andy Davis (voice: John Morris) is 17 years ol...
# 1       22186  tt1375666  A young man, exhausted and delirious, washes u...
# 2        3843  tt0892791  The movie begins just before Shrek (voiced by ...
# 3        4909  tt1325004  Eclipse opens at nighttime where Riley Biers (...
# 4       12368  tt1228705  The movie opens several months after the event...
#
#                                                 tags  split synopsis_source
# 0  comedy, boring, violence, flashback, good vers...  train            imdb
# 1  boring, neo noir, murder, sentimental, fantasy...    val            imdb
# 2                            comedy, fantasy, action  train            imdb
# 3  paranormal, revenge, murder, entertaining, fla...  train            imdb
# 4   good versus evil, revenge, humor, action, murder  train            imdb

# %%
bom_tmdb_mpst_df.shape
# Out:
# (1282, 19)

# %%
import pandas as pd

imdb_name_df = pd.read_csv('./zippedData/imdb.name.basics.csv')

# %%
imdb_name_df.head()
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256

# %%
imdb_title_df = pd.read_csv('./zippedData/imdb.title.akas.csv')

imdb_title_df.head()
# Out:
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0

# %%
imdb_title_basics_df = pd.read_csv('./zippedData/imdb.title.basics.csv')

imdb_title_basics_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
imdb_title_basics_df.rename(columns = {'primary_title': 'title'}, inplace = True)

# %%
tmdb_imdb_df = pd.merge(imdb_title_basics_df, tmdb_df, on = 'title', how = 'inner')

tmdb_imdb_df.head()
# Out:
#       tconst                       title            original_title_x  \
# 0  tt0069049  The Other Side of the Wind  The Other Side of the Wind
# 1  tt0112502                     Bigfoot                     Bigfoot
# 2  tt4503112                     Bigfoot                     Bigfoot
# 3  tt9181914                     Bigfoot                     Bigfoot
# 4  tt0192528               Heaven & Hell              Reverse Heaven
#
#    start_year  runtime_minutes            genres  Unnamed: 0      genre_ids  \
# 0        2018            122.0             Drama       24185       [35, 18]
# 1        2017              NaN   Horror,Thriller        5872  [27, 878, 12]
# 2        2018              NaN     Action,Horror        5872  [27, 878, 12]
# 3        2018             86.0  Animation,Family        5872  [27, 878, 12]
# 4        2018            104.0             Drama       26332           [18]
#
#        id original_language            original_title_y  popularity  \
# 0  299782                en  The Other Side of the Wind       9.800
# 1  117856                en                     Bigfoot       2.813
# 2  117856                en                     Bigfoot       2.813
# 3  117856                en                     Bigfoot       2.813
# 4  567662                en               Heaven & Hell       0.600
#
#   release_date  vote_average  vote_count
# 0   2018-11-02           7.0          64
# 1   2012-06-30           2.9          26
# 2   2012-06-30           2.9          26
# 3   2012-06-30           2.9          26
# 4   2018-11-06           7.5           2

# %%
imdb_title_ratings_df = pd.read_csv('./zippedData/imdb.title.ratings.csv')

imdb_title_ratings_df.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
rating_tmdb_imdb_df = pd.merge(tmdb_imdb_df, imdb_title_ratings_df, on='tconst', how = 'inner')

# %%
rating_tmdb_imdb_df.head()
# Out:
#       tconst                       title            original_title_x  \
# 0  tt0069049  The Other Side of the Wind  The Other Side of the Wind
# 1  tt0112502                     Bigfoot                     Bigfoot
# 2  tt4503112                     Bigfoot                     Bigfoot
# 3  tt9181914                     Bigfoot                     Bigfoot
# 4  tt0192528               Heaven & Hell              Reverse Heaven
#
#    start_year  runtime_minutes            genres  Unnamed: 0      genre_ids  \
# 0        2018            122.0             Drama       24185       [35, 18]
# 1        2017              NaN   Horror,Thriller        5872  [27, 878, 12]
# 2        2018              NaN     Action,Horror        5872  [27, 878, 12]
# 3        2018             86.0  Animation,Family        5872  [27, 878, 12]
# 4        2018            104.0             Drama       26332           [18]
#
#        id original_language            original_title_y  popularity  \
# 0  299782                en  The Other Side of the Wind       9.800
# 1  117856                en                     Bigfoot       2.813
# 2  117856                en                     Bigfoot       2.813
# 3  117856                en                     Bigfoot       2.813
# 4  567662                en               Heaven & Hell       0.600
#
#   release_date  vote_average  vote_count  averagerating  numvotes
# 0   2018-11-02           7.0          64            6.9      4517
# 1   2012-06-30           2.9          26            4.1        32
# 2   2012-06-30           2.9          26            4.6         9
# 3   2012-06-30           2.9          26            2.5        55
# 4   2018-11-06           7.5           2            4.0        72

# %%
merged_df = pd.merge(rating_tmdb_imdb_df, bom_tmdb_mpst_df, on='title', how='inner')

# %%
merged_df.head()
# Out:
#       tconst                        title             original_title_x  \
# 0  tt0337692                  On the Road                  On the Road
# 1  tt4339118                  On the Road                  On the Road
# 2  tt5647250                  On the Road                  On the Road
# 3  tt0365907  A Walk Among the Tombstones  A Walk Among the Tombstones
# 4  tt0369610               Jurassic World               Jurassic World
#
#    start_year  runtime_minutes                   genres  Unnamed: 0_x  \
# 0        2012            124.0  Adventure,Drama,Romance          5350
# 1        2014             89.0                    Drama          5350
# 2        2016            121.0                    Drama          5350
# 3        2014            114.0       Action,Crime,Drama         11053
# 4        2015            124.0  Action,Adventure,Sci-Fi         14193
#
#           genre_ids_x    id_x original_language_x  ...  \
# 0            [12, 18]   83770                  en  ...
# 1            [12, 18]   83770                  en  ...
# 2            [12, 18]   83770                  en  ...
# 3  [80, 18, 9648, 53]  169917                  en  ...
# 4   [28, 12, 878, 53]  135397                  en  ...
#
#                 original_title  popularity_y release_date_y  vote_average_y  \
# 0                  On the Road         8.919     2012-12-21             5.6
# 1                  On the Road         8.919     2012-12-21             5.6
# 2                  On the Road         8.919     2012-12-21             5.6
# 3  A Walk Among the Tombstones        19.373     2014-09-19             6.3
# 4               Jurassic World        20.709     2015-06-12             6.6
#
#    vote_count_y    imdb_id                                      plot_synopsis  \
# 0           518  tt0337692  The two main characters of the book are the na...
# 1           518  tt0337692  The two main characters of the book are the na...
# 2           518  tt0337692  The two main characters of the book are the na...
# 3          1685  tt0365907  New York City, 1991Detective Matt Scudder (Lia...
# 4         14056  tt0369610  Following the demise of dinosaur-themed Jurass...
#
#                                                 tags  split synopsis_source
# 0                                          flashback  train       wikipedia
# 1                                          flashback  train       wikipedia
# 2                                          flashback  train       wikipedia
# 3  suspenseful, neo noir, murder, violence, flash...    val            imdb
# 4                                   violence, satire  train       wikipedia
#
# [5 rows x 35 columns]

# %%
merged_df.columns
# Out:
# Index(['tconst', 'title', 'original_title_x', 'start_year', 'runtime_minutes',
#        'genres', 'Unnamed: 0_x', 'genre_ids_x', 'id_x', 'original_language_x',
#        'original_title_y', 'popularity_x', 'release_date_x', 'vote_average_x',
#        'vote_count_x', 'averagerating', 'numvotes', 'studio', 'domestic_gross',
#        'foreign_gross', 'year', 'Unnamed: 0_y', 'genre_ids_y', 'id_y',
#        'original_language_y', 'original_title', 'popularity_y',
#        'release_date_y', 'vote_average_y', 'vote_count_y', 'imdb_id',
#        'plot_synopsis', 'tags', 'split', 'synopsis_source'],
#       dtype='object')

# %%
merged_df.drop(columns=['original_title_x', 'start_year', 'Unnamed: 0_x', 'genre_ids_x', 'original_language_x', 'original_title_y', 'popularity_x', 'release_date_x', 'vote_average_x', 'vote_count_x', 'foreign_gross', 'year', 'Unnamed: 0_y', 'genre_ids_y', 'original_language_y', 'original_title', 'imdb_id', 'plot_synopsis', 'split', 'synopsis_source',], inplace=True)

# %%
merged_df.drop(columns=['runtime_minutes', 'id_y', 'tags'], inplace=True)
merged_df.head()
# Out:
#       tconst                        title                   genres    id_x  \
# 0  tt0337692                  On the Road  Adventure,Drama,Romance   83770
# 1  tt4339118                  On the Road                    Drama   83770
# 2  tt5647250                  On the Road                    Drama   83770
# 3  tt0365907  A Walk Among the Tombstones       Action,Crime,Drama  169917
# 4  tt0369610               Jurassic World  Action,Adventure,Sci-Fi  135397
#
#    averagerating  numvotes studio  domestic_gross  popularity_y  \
# 0            6.1     37886    IFC        744000.0         8.919
# 1            6.0         6    IFC        744000.0         8.919
# 2            5.7       127    IFC        744000.0         8.919
# 3            6.5    105116   Uni.      26300000.0        19.373
# 4            7.0    539338   Uni.     652300000.0        20.709
#
#   release_date_y  vote_average_y  vote_count_y
# 0     2012-12-21             5.6           518
# 1     2012-12-21             5.6           518
# 2     2012-12-21             5.6           518
# 3     2014-09-19             6.3          1685
# 4     2015-06-12             6.6         14056

# %%
merged_df.drop(columns=['id_x'], inplace=True)

# %%
merged_df.rename(columns={'popularity_y':'popularity', 'release_date_y':'release_date', 'vote_average_y':'vote_average', 'vote_count_y':'vote_count'}, inplace=True)

# %%
merged_df.head()
# Out:
#       tconst                        title                   genres  \
# 0  tt0337692                  On the Road  Adventure,Drama,Romance
# 1  tt4339118                  On the Road                    Drama
# 2  tt5647250                  On the Road                    Drama
# 3  tt0365907  A Walk Among the Tombstones       Action,Crime,Drama
# 4  tt0369610               Jurassic World  Action,Adventure,Sci-Fi
#
#    averagerating  numvotes studio  domestic_gross  popularity release_date  \
# 0            6.1     37886    IFC        744000.0       8.919   2012-12-21
# 1            6.0         6    IFC        744000.0       8.919   2012-12-21
# 2            5.7       127    IFC        744000.0       8.919   2012-12-21
# 3            6.5    105116   Uni.      26300000.0      19.373   2014-09-19
# 4            7.0    539338   Uni.     652300000.0      20.709   2015-06-12
#
#    vote_average  vote_count
# 0           5.6         518
# 1           5.6         518
# 2           5.6         518
# 3           6.3        1685
# 4           6.6       14056

# %%
merged_df.shape
# Out:
# (2556, 11)

# %%
merged_df.drop_duplicates(subset='domestic_gross', inplace=True)

# %%
merged_df.head()
# Out:
#        tconst                        title                   genres  \
# 0   tt0337692                  On the Road  Adventure,Drama,Romance
# 3   tt0365907  A Walk Among the Tombstones       Action,Crime,Drama
# 4   tt0369610               Jurassic World  Action,Adventure,Sci-Fi
# 5   tt0372538                          Spy       Action,Crime,Drama
# 13  tt0376479            American Pastoral              Crime,Drama
#
#     averagerating  numvotes studio  domestic_gross  popularity release_date  \
# 0             6.1     37886    IFC        744000.0       8.919   2012-12-21
# 3             6.5    105116   Uni.      26300000.0      19.373   2014-09-19
# 4             7.0    539338   Uni.     652300000.0      20.709   2015-06-12
# 5             6.6        78    Fox     110800000.0       1.400   2011-08-09
# 13            6.1     12898    LGF        544000.0       7.782   2016-10-21
#
#     vote_average  vote_count
# 0            5.6         518
# 3            6.3        1685
# 4            6.6       14056
# 5            7.0           1
# 13           6.0         339

# %%
merged_df.shape
# Out:
# (721, 11)

# %%
type(merged_df['genres'][0])
# Out:
# str

# %%
type(merged_df['release_date'][0])
# Out:
# str

# %%
merged_df['month'] = merged_df['release_date'].apply(lambda x: x.split('-'))

# %%
from dateutil.parser import parse

# %%
merged_df['release_date'] = merged_df['release_date'].apply(lambda x: parse(x))

# %%
merged_df.head()
# Out:
#        tconst                        title                   genres  \
# 0   tt0337692                  On the Road  Adventure,Drama,Romance
# 3   tt0365907  A Walk Among the Tombstones       Action,Crime,Drama
# 4   tt0369610               Jurassic World  Action,Adventure,Sci-Fi
# 5   tt0372538                          Spy       Action,Crime,Drama
# 13  tt0376479            American Pastoral              Crime,Drama
#
#     averagerating  numvotes studio  domestic_gross  popularity release_date  \
# 0             6.1     37886    IFC        744000.0       8.919   2012-12-21
# 3             6.5    105116   Uni.      26300000.0      19.373   2014-09-19
# 4             7.0    539338   Uni.     652300000.0      20.709   2015-06-12
# 5             6.6        78    Fox     110800000.0       1.400   2011-08-09
# 13            6.1     12898    LGF        544000.0       7.782   2016-10-21
#
#     vote_average  vote_count           month
# 0            5.6         518  [2012, 12, 21]
# 3            6.3        1685  [2014, 09, 19]
# 4            6.6       14056  [2015, 06, 12]
# 5            7.0           1  [2011, 08, 09]
# 13           6.0         339  [2016, 10, 21]

# %%
merged_df['month'] = merged_df['release_date']

# %%
merged_df['month'] = merged_df['month'].apply(lambda x: x.month)

# %%
merged_df.head()
# Out:
#        tconst                        title                   genres  \
# 0   tt0337692                  On the Road  Adventure,Drama,Romance
# 3   tt0365907  A Walk Among the Tombstones       Action,Crime,Drama
# 4   tt0369610               Jurassic World  Action,Adventure,Sci-Fi
# 5   tt0372538                          Spy       Action,Crime,Drama
# 13  tt0376479            American Pastoral              Crime,Drama
#
#     averagerating  numvotes studio  domestic_gross  popularity release_date  \
# 0             6.1     37886    IFC        744000.0       8.919   2012-12-21
# 3             6.5    105116   Uni.      26300000.0      19.373   2014-09-19
# 4             7.0    539338   Uni.     652300000.0      20.709   2015-06-12
# 5             6.6        78    Fox     110800000.0       1.400   2011-08-09
# 13            6.1     12898    LGF        544000.0       7.782   2016-10-21
#
#     vote_average  vote_count  month
# 0            5.6         518     12
# 3            6.3        1685      9
# 4            6.6       14056      6
# 5            7.0           1      8
# 13           6.0         339     10

# %%
merged_df['genres'] = merged_df['genres'].apply(lambda x: x.split(','))
merged_df.head()
# Out:
#        tconst                        title                       genres  \
# 0   tt0337692                  On the Road  [Adventure, Drama, Romance]
# 3   tt0365907  A Walk Among the Tombstones       [Action, Crime, Drama]
# 4   tt0369610               Jurassic World  [Action, Adventure, Sci-Fi]
# 5   tt0372538                          Spy       [Action, Crime, Drama]
# 13  tt0376479            American Pastoral               [Crime, Drama]
#
#     averagerating  numvotes studio  domestic_gross  popularity release_date  \
# 0             6.1     37886    IFC        744000.0       8.919   2012-12-21
# 3             6.5    105116   Uni.      26300000.0      19.373   2014-09-19
# 4             7.0    539338   Uni.     652300000.0      20.709   2015-06-12
# 5             6.6        78    Fox     110800000.0       1.400   2011-08-09
# 13            6.1     12898    LGF        544000.0       7.782   2016-10-21
#
#     vote_average  vote_count  month
# 0            5.6         518     12
# 3            6.3        1685      9
# 4            6.6       14056      6
# 5            7.0           1      8
# 13           6.0         339     10

# %%
merged_df.drop(columns=['genre'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-130-f8f23ea7249a> in <module>
# ----> 1 merged_df.drop(columns=['genre'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['genre'] not found in axis"

# %%
avg_gross_month = merged_df.groupby(['month']).mean()['domestic_gross']
avg_gross_month
# Out:
# month
# 1     4.169886e+07
# 2     5.847270e+07
# 3     6.691723e+07
# 4     3.518441e+07
# 5     9.662538e+07
# 6     1.017212e+08
# 7     8.840903e+07
# 8     5.423179e+07
# 9     5.068872e+07
# 10    4.036132e+07
# 11    8.287959e+07
# 12    7.692566e+07
# Name: domestic_gross, dtype: float64

# %%
jan_df = merged_df[merged_df['month']==1]

# %%
jan_df.head()
# Out:
#         tconst                title                        genres  \
# 85   tt0472399         The Mechanic     [Action, Crime, Thriller]
# 141  tt0479997  Season of the Witch  [Action, Adventure, Fantasy]
# 167  tt0808510          Tooth Fairy     [Comedy, Family, Fantasy]
# 196  tt0882977               Snitch     [Action, Drama, Thriller]
# 204  tt0884732   The Wedding Ringer                      [Comedy]
#
#      averagerating  numvotes studio  domestic_gross  popularity release_date  \
# 85             6.6    141254    CBS      29100000.0      14.387   2011-01-28
# 141            5.4     85777  Rela.      24800000.0      12.535   2011-01-07
# 167            5.0     37939    Fox      60000000.0      12.650   2010-01-22
# 196            6.5     78142   LG/S      42900000.0       0.600   2011-01-01
# 204            6.7     66893   SGem      64500000.0      15.876   2015-01-16
#
#      vote_average  vote_count  month
# 85            6.3        1676      1
# 141           5.3        1352      1
# 167           5.3        1058      1
# 196           1.0           1      1
# 204           6.5         961      1

# %%
feb_df = merged_df[merged_df['month']==2]
march_df = merged_df[merged_df['month']==3]
april_df = merged_df[merged_df['month']==4]
may_df = merged_df[merged_df['month']==5]
jun_df = merged_df[merged_df['month']==6]
jul_df = merged_df[merged_df['month']==7]
aug_df = merged_df[merged_df['month']==8]
sept_df = merged_df[merged_df['month']==9]
oct_df = merged_df[merged_df['month']==10]
nov_df = merged_df[merged_df['month']==11]
dec_df = merged_df[merged_df['month']==12]

# %%
dec_df.head()
# Out:
#         tconst                              title  \
# 0    tt0337692                        On the Road
# 138  tt0477302  Extremely Loud & Incredibly Close
# 161  tt0790724                       Jack Reacher
# 210  tt0903624  The Hobbit: An Unexpected Journey
# 214  tt0935075                        Rabbit Hole
#
#                            genres  averagerating  numvotes   studio  \
# 0     [Adventure, Drama, Romance]            6.1     37886      IFC
# 138   [Adventure, Drama, Mystery]            6.9     93164       WB
# 161     [Action, Crime, Thriller]            7.0    284547     Par.
# 210  [Adventure, Family, Fantasy]            7.9    719629  WB (NL)
# 214                       [Drama]            7.0     45357      LGF
#
#      domestic_gross  popularity release_date  vote_average  vote_count  month
# 0          744000.0       8.919   2012-12-21           5.6         518     12
# 138      31800000.0       9.828   2011-12-24           7.0        1231     12
# 161      80100000.0      18.312   2012-12-21           6.4        4155     12
# 210     303000000.0      26.939   2012-12-14           7.2       12076     12
# 214       2200000.0       9.389   2010-12-16           6.8         292     12

# %%
merged_df.head()
# Out:
#        tconst                        title                       genres  \
# 0   tt0337692                  On the Road  [Adventure, Drama, Romance]
# 3   tt0365907  A Walk Among the Tombstones       [Action, Crime, Drama]
# 4   tt0369610               Jurassic World  [Action, Adventure, Sci-Fi]
# 5   tt0372538                          Spy       [Action, Crime, Drama]
# 13  tt0376479            American Pastoral               [Crime, Drama]
#
#     averagerating  numvotes studio  domestic_gross  popularity release_date  \
# 0             6.1     37886    IFC        744000.0       8.919   2012-12-21
# 3             6.5    105116   Uni.      26300000.0      19.373   2014-09-19
# 4             7.0    539338   Uni.     652300000.0      20.709   2015-06-12
# 5             6.6        78    Fox     110800000.0       1.400   2011-08-09
# 13            6.1     12898    LGF        544000.0       7.782   2016-10-21
#
#     vote_average  vote_count  month
# 0            5.6         518     12
# 3            6.3        1685      9
# 4            6.6       14056      6
# 5            7.0           1      8
# 13           6.0         339     10

# %%
import seaborn as sns

ax = sns.boxplot(x="month", y="domestic_gross", data=merged_df, palette="Set3").set(ylabel= "Domestic Gross")

plt.show()
