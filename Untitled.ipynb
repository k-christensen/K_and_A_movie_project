# %%
import pandas as pd

pd.read_csv('top_three_genres.csv')
# Out:
#            studio  month  day            genre  domestic_gross
# 0              BV      6  mid     comedy_gross     415000000.0
# 1            P/DW      5  mid     comedy_gross     238700000.0
# 2              BV     11  end     comedy_gross     200800000.0
# 3            Uni.      7  beg     comedy_gross     251500000.0
# 4            P/DW     11  beg     comedy_gross     148400000.0
# 5            Uni.     12  end     comedy_gross     148400000.0
# 6         WB (NL)      5  end     comedy_gross      95300000.0
# 7            Sony      6  end     comedy_gross     162000000.0
# 8             Fox     12  end     comedy_gross      42800000.0
# 9         WB (NL)      2  mid     comedy_gross     110500000.0
# 10             WB     11  beg     comedy_gross     100500000.0
# 11             WB     12  mid     comedy_gross     100200000.0
# 12           Sony      8  beg     comedy_gross     119200000.0
# 13            Fox      4  beg     comedy_gross      98700000.0
# ...
